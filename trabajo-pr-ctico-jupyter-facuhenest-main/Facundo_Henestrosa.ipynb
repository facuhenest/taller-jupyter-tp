# %% [markdown]
# # [EXERCISE 1]
# ## Facundo Henestrosa
# ## fhenestrosa@mail.austral.edu.ar
#
# ![image.png](attachment:c6ccee00-0aee-41e9-99e1-72055d7defd1.png)
#
# messi, con la champions 2015.

# %% [markdown]
# # [EXERCISE 5]

# %%
a=3
b=7

# %% [markdown]
# # sum

# %%
print(a+b)
# Out:
# 10

# %% [markdown]
# # substraction

# %%
print(a - b)
# Out:
# -4

# %% [markdown]
# # multiplication

# %%
print(a * b)
# Out:
# 21

# %% [markdown]
# # division

# %%
print(a / b)
# Out:
# 0.42857142857142855
